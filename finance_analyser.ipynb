# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import streamlit
import sklearn
import seaborn
print("All libraries working! Project setup complete!")
# Out:
# All libraries working! Project setup complete!
